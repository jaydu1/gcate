# %%
import os
import sys
os.environ["OMP_NUM_THREADS"] = "11"
os.environ["OPENBLAS_NUM_THREADS"] = "8" # export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = "11" # export MKL_NUM_THREADS=6
os.environ["VECLIB_MAXIMUM_THREADS"] = "8" # export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = "11" # export NUMEXPR_NUM_THREADS=6
os.environ["NUMBA_CACHE_DIR"]='/tmp/numba_cache'

import numpy as np
import pandas as pd
import scipy as sp
import scipy.stats
from tqdm import tqdm
import statsmodels.api as sm
from statsmodels.stats.multitest import multipletests
import matplotlib.pyplot as plt
import seaborn as sns
import dill

import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
params = {"ytick.color" : "black",
          "xtick.color" : "black",
          "axes.labelcolor" : "black",
          "axes.edgecolor" : "black",
          "font.family" : "serif",
          "font.serif" : ["Computer Modern Serif"]}
plt.rcParams.update(params)

path_data = 'data/lupus/'
path_result = 'result/lupus/'

# %% [markdown]
# # Selection of the number of latent factors

# %%
from gcate import *
from gcate import plot_r, plot_lam
sns.set(font_scale=1.5, style='white')


cell_types = ['T4', 'cM', 'B', 'T8', 'NK']

for cell_type in cell_types:
    print(cell_type)

    file_name = path_data + 'data_lupus_{}.npz'.format(cell_type)
    with open(file_name, 'rb') as f:
        tmp = np.load(f)
        X = tmp['X']
        Y = tmp['Y'].astype(float)
        X = X * 2 - 1
        X = np.c_[np.ones(X.shape[0]), np.log(np.sum(Y, axis=1)), X]
        X = X / np.sqrt(np.sum(X**2, 0, keepdims=True)) * np.sqrt(X.shape[0])
    X_sub = np.c_[X[:,:2],X[:,-1:]]
    id_genes = np.any(Y, axis=0) & (np.sum(Y>0, axis=0)>=10)
    p_all = Y.shape[1]
    Y = Y[:,id_genes]
    print(X.shape, X_sub.shape, Y.shape)

    p = Y.shape[1]
    d = X.shape[1]

    with open('result/lupus/dill_{}.pkl'.format(cell_type), "rb") as file_object:
        [
            B_glm,tvals,pvals,_df_glm,disp_glm,
            B_glm_nb,tvals_glm_nb,pvals_glm_nb,_df_glm_nb,
            B_glm_sub,tvals_sub,pvals_sub,_df_glm_sub,disp_glm_sub,
            B_glm_nb_sub,tvals_glm_nb_sub,pvals_glm_nb_sub,_df_glm_nb_sub
        ] = dill.load(file_object)

    kwargs_glm = {
            'family':'negative_binomial',
            'nuisance':1/disp_glm_sub[None,:]
        }

    r_max = 10
    df_r = estimate_r(Y, X_sub, r_max, 
        kwargs_glm=kwargs_glm, 
        kwargs_ls_1={'alpha':0.1}, kwargs_es_1={'max_iters': 2000},
        kwargs_ls_2={'alpha':0.01}, kwargs_es_2={'max_iters': 2000, 'patience':25},
        c1=0.01, intercept=1, offset=0, C=1e3, verbose=False
    )

    
    c = 0.2 if cell_type == 'NK' else 0.25
    fig = plot_r(df_r, c=c)
    fig.savefig(path_result + 'lupus_{}_r.pdf'.format(cell_type), bbox_inches='tight')
# Out:
# T4
# (256, 8) (256, 3) (256, 1255)
#   8%|▊         | 153/2000 [00:37<07:32,  4.08it/s, nll=2.56]
# Best Epoch: 132. Best Metric: 2.561441.
# Early stopped.
#   2%|▏         | 31/2000 [00:21<23:02,  1.42it/s, nll=2.56]
# Best Epoch: 5. Best Metric: 2.561711.
# Early stopped.
#  14%|█▎        | 271/2000 [00:12<01:22, 20.96it/s, nll=2.56]
# Best Epoch: 250. Best Metric: 2.555498.
# Early stopped.
#   2%|▏         | 31/2000 [00:02<02:08, 15.38it/s, nll=2.56]
# Best Epoch: 5. Best Metric: 2.555697.
# Early stopped.
#  23%|██▎       | 455/2000 [00:21<01:13, 21.08it/s, nll=2.55]
# Best Epoch: 434. Best Metric: 2.549984.
# Early stopped.
#   2%|▏         | 31/2000 [00:01<02:01, 16.20it/s, nll=2.55]
# Best Epoch: 5. Best Metric: 2.550119.
# Early stopped.
#  24%|██▍       | 484/2000 [00:23<01:14, 20.44it/s, nll=2.55]
# Best Epoch: 463. Best Metric: 2.546630.
# Early stopped.
#   2%|▏         | 40/2000 [00:02<02:03, 15.84it/s, nll=2.55]
# Best Epoch: 14. Best Metric: 2.546622.
# Early stopped.
#  27%|██▋       | 541/2000 [00:26<01:11, 20.34it/s, nll=2.54]
# Best Epoch: 520. Best Metric: 2.543306.
# Early stopped.
#   2%|▏         | 37/2000 [00:02<02:05, 15.69it/s, nll=2.54]
# Best Epoch: 11. Best Metric: 2.543261.
# Early stopped.
#  29%|██▉       | 588/2000 [00:29<01:09, 20.22it/s, nll=2.54]
# Best Epoch: 567. Best Metric: 2.540020.
# Early stopped.
#   2%|▏         | 41/2000 [00:02<01:55, 16.93it/s, nll=2.54]
# Best Epoch: 15. Best Metric: 2.539817.
# Early stopped.
#  31%|███       | 624/2000 [00:30<01:07, 20.33it/s, nll=2.54]
# Best Epoch: 603. Best Metric: 2.536994.
# Early stopped.
#   2%|▏         | 48/2000 [00:02<02:00, 16.21it/s, nll=2.54]
# Best Epoch: 22. Best Metric: 2.536630.
# Early stopped.
#  33%|███▎      | 653/2000 [00:33<01:08, 19.77it/s, nll=2.54]
# Best Epoch: 632. Best Metric: 2.535124.
# Early stopped.
#   3%|▎         | 55/2000 [00:03<02:00, 16.12it/s, nll=2.53]
# Best Epoch: 29. Best Metric: 2.534650.
# Early stopped.
#  35%|███▍      | 697/2000 [00:34<01:04, 20.07it/s, nll=2.53]
# Best Epoch: 676. Best Metric: 2.532936.
# Early stopped.
#   3%|▎         | 51/2000 [00:03<01:59, 16.32it/s, nll=2.53]
# Best Epoch: 25. Best Metric: 2.532419.
# Early stopped.
#  37%|███▋      | 744/2000 [00:37<01:03, 19.75it/s, nll=2.53]
# Best Epoch: 723. Best Metric: 2.531076.
# Early stopped.
#   3%|▎         | 66/2000 [00:04<01:59, 16.22it/s, nll=2.53]
# Best Epoch: 40. Best Metric: 2.530410.
# Early stopped.
# cM
# (256, 8) (256, 3) (256, 1208)
#   9%|▉         | 183/2000 [00:08<01:24, 21.57it/s, nll=2.70]
# Best Epoch: 162. Best Metric: 2.699758.
# Early stopped.
#   2%|▏         | 31/2000 [00:01<02:00, 16.34it/s, nll=2.70]
# Best Epoch: 5. Best Metric: 2.700007.
# Early stopped.
#  12%|█▏        | 237/2000 [00:10<01:18, 22.55it/s, nll=2.69]
# Best Epoch: 216. Best Metric: 2.694682.
# Early stopped.
#   2%|▏         | 31/2000 [00:01<01:54, 17.17it/s, nll=2.69]
# Best Epoch: 5. Best Metric: 2.694875.
# Early stopped.
#  17%|█▋        | 331/2000 [00:15<01:16, 21.71it/s, nll=2.69]
# Best Epoch: 310. Best Metric: 2.689845.
# Early stopped.
#   2%|▏         | 31/2000 [00:01<01:53, 17.29it/s, nll=2.69]
# Best Epoch: 5. Best Metric: 2.690004.
# Early stopped.
#  22%|██▏       | 439/2000 [00:19<01:09, 22.38it/s, nll=2.69]
# Best Epoch: 418. Best Metric: 2.685289.
# Early stopped.
#   2%|▏         | 38/2000 [00:02<01:54, 17.17it/s, nll=2.69]
# Best Epoch: 12. Best Metric: 2.685287.
# Early stopped.
#  25%|██▌       | 505/2000 [00:24<01:11, 20.91it/s, nll=2.68]
# Best Epoch: 484. Best Metric: 2.682203.
# Early stopped.
#   2%|▏         | 44/2000 [00:02<01:58, 16.49it/s, nll=2.68]
# Best Epoch: 18. Best Metric: 2.682039.
# Early stopped.
#  28%|██▊       | 551/2000 [00:26<01:10, 20.68it/s, nll=2.68]
# Best Epoch: 530. Best Metric: 2.678935.
# Early stopped.
#   2%|▏         | 49/2000 [00:02<01:53, 17.13it/s, nll=2.68]
# Best Epoch: 23. Best Metric: 2.678624.
# Early stopped.
#  30%|███       | 605/2000 [00:28<01:06, 21.00it/s, nll=2.68]
# Best Epoch: 584. Best Metric: 2.676291.
# Early stopped.
#   3%|▎         | 63/2000 [00:03<01:57, 16.43it/s, nll=2.68]
# Best Epoch: 37. Best Metric: 2.675824.
# Early stopped.
#  32%|███▏      | 631/2000 [00:30<01:05, 20.92it/s, nll=2.67]
# Best Epoch: 610. Best Metric: 2.674549.
# Early stopped.
#   3%|▎         | 51/2000 [00:02<01:52, 17.26it/s, nll=2.67]
# Best Epoch: 25. Best Metric: 2.674095.
# Early stopped.
#  34%|███▎      | 673/2000 [00:31<01:02, 21.11it/s, nll=2.67]
# Best Epoch: 652. Best Metric: 2.672501.
# Early stopped.
#   3%|▎         | 63/2000 [00:03<01:53, 17.00it/s, nll=2.67]
# Best Epoch: 37. Best Metric: 2.671928.
# Early stopped.
#  35%|███▍      | 698/2000 [00:33<01:01, 21.03it/s, nll=2.67]
# Best Epoch: 677. Best Metric: 2.670567.
# Early stopped.
#   3%|▎         | 58/2000 [00:03<01:55, 16.88it/s, nll=2.67]
# Best Epoch: 32. Best Metric: 2.669950.
# Early stopped.
# B
# (254, 8) (254, 3) (254, 1269)
#   8%|▊         | 166/2000 [00:07<01:26, 21.13it/s, nll=2.04]
# Best Epoch: 145. Best Metric: 2.043385.
# Early stopped.
#   2%|▏         | 31/2000 [00:02<02:08, 15.36it/s, nll=2.04]
# Best Epoch: 5. Best Metric: 2.043601.
# Early stopped.
#  15%|█▌        | 303/2000 [00:13<01:15, 22.51it/s, nll=2.04]
# Best Epoch: 282. Best Metric: 2.037905.
# Early stopped.
#   2%|▏         | 31/2000 [00:01<01:56, 16.84it/s, nll=2.04]
# Best Epoch: 5. Best Metric: 2.038068.
# Early stopped.
#  21%|██        | 412/2000 [00:19<01:13, 21.61it/s, nll=2.03]
# Best Epoch: 391. Best Metric: 2.033943.
# Early stopped.
#   2%|▏         | 31/2000 [00:01<01:49, 17.96it/s, nll=2.03]
# Best Epoch: 5. Best Metric: 2.034073.
# Early stopped.
#  23%|██▎       | 468/2000 [00:21<01:08, 22.22it/s, nll=2.03]
# Best Epoch: 447. Best Metric: 2.031049.
# Early stopped.
#   2%|▏         | 31/2000 [00:01<01:57, 16.69it/s, nll=2.03]
# Best Epoch: 5. Best Metric: 2.031140.
# Early stopped.
#  26%|██▌       | 519/2000 [00:25<01:11, 20.72it/s, nll=2.03]
# Best Epoch: 498. Best Metric: 2.027629.
# Early stopped.
#   2%|▏         | 38/2000 [00:02<01:59, 16.39it/s, nll=2.03]
# Best Epoch: 12. Best Metric: 2.027581.
# Early stopped.
#  28%|██▊       | 567/2000 [00:27<01:09, 20.63it/s, nll=2.02]
# Best Epoch: 546. Best Metric: 2.024921.
# Early stopped.
#   2%|▏         | 49/2000 [00:02<01:58, 16.50it/s, nll=2.02]
# Best Epoch: 23. Best Metric: 2.024740.
# Early stopped.
#  30%|██▉       | 595/2000 [00:28<01:06, 21.23it/s, nll=2.02]
# Best Epoch: 574. Best Metric: 2.022750.
# Early stopped.
#   2%|▏         | 43/2000 [00:02<01:49, 17.82it/s, nll=2.02]
# Best Epoch: 17. Best Metric: 2.022533.
# Early stopped.
#  32%|███▏      | 638/2000 [00:30<01:04, 21.13it/s, nll=2.02]
# Best Epoch: 617. Best Metric: 2.020837.
# Early stopped.
#   2%|▎         | 50/2000 [00:02<01:50, 17.63it/s, nll=2.02]
# Best Epoch: 24. Best Metric: 2.020502.
# Early stopped.
#  34%|███▍      | 681/2000 [00:32<01:02, 21.01it/s, nll=2.02]
# Best Epoch: 660. Best Metric: 2.019177.
# Early stopped.
#   3%|▎         | 62/2000 [00:03<01:58, 16.36it/s, nll=2.02]
# Best Epoch: 36. Best Metric: 2.018725.
# Early stopped.
#  35%|███▌      | 707/2000 [00:34<01:03, 20.48it/s, nll=2.02]
# Best Epoch: 686. Best Metric: 2.017230.
# Early stopped.
#   3%|▎         | 56/2000 [00:03<01:51, 17.37it/s, nll=2.02]
# Best Epoch: 30. Best Metric: 2.016740.
# Early stopped.
# T8
# (256, 8) (256, 3) (256, 1281)
#   9%|▉         | 179/2000 [00:08<01:22, 22.02it/s, nll=2.40]
# Best Epoch: 158. Best Metric: 2.398299.
# Early stopped.
#   2%|▏         | 31/2000 [00:01<01:58, 16.57it/s, nll=2.40]
# Best Epoch: 5. Best Metric: 2.398429.
# Early stopped.
#  12%|█▏        | 246/2000 [00:11<01:21, 21.47it/s, nll=2.39]
# Best Epoch: 225. Best Metric: 2.392506.
# Early stopped.
#   2%|▏         | 40/2000 [00:02<01:57, 16.65it/s, nll=2.39]
# Best Epoch: 14. Best Metric: 2.392479.
# Early stopped.
#  18%|█▊        | 353/2000 [00:16<01:17, 21.24it/s, nll=2.39]
# Best Epoch: 332. Best Metric: 2.388229.
# Early stopped.
#   2%|▏         | 46/2000 [00:02<01:52, 17.41it/s, nll=2.39]
# Best Epoch: 20. Best Metric: 2.388053.
# Early stopped.
#  20%|██        | 408/2000 [00:19<01:15, 21.06it/s, nll=2.38]
# Best Epoch: 387. Best Metric: 2.384778.
# Early stopped.
#   2%|▏         | 41/2000 [00:02<01:56, 16.75it/s, nll=2.38]
# Best Epoch: 15. Best Metric: 2.384551.
# Early stopped.
#  23%|██▎       | 451/2000 [00:22<01:17, 20.09it/s, nll=2.38]
# Best Epoch: 430. Best Metric: 2.381640.
# Early stopped.
#   3%|▎         | 54/2000 [00:03<01:59, 16.32it/s, nll=2.38]
# Best Epoch: 28. Best Metric: 2.381119.
# Early stopped.
#  23%|██▎       | 468/2000 [00:23<01:17, 19.89it/s, nll=2.38]
# Best Epoch: 447. Best Metric: 2.378932.
# Early stopped.
#   3%|▎         | 64/2000 [00:04<02:01, 15.98it/s, nll=2.38]
# Best Epoch: 38. Best Metric: 2.378247.
# Early stopped.
#  25%|██▌       | 506/2000 [00:25<01:15, 19.84it/s, nll=2.38]
# Best Epoch: 485. Best Metric: 2.376592.
# Early stopped.
#   3%|▎         | 66/2000 [00:04<01:59, 16.21it/s, nll=2.38]
# Best Epoch: 40. Best Metric: 2.375784.
# Early stopped.
#  27%|██▋       | 533/2000 [00:25<01:10, 20.76it/s, nll=2.37]
# Best Epoch: 512. Best Metric: 2.373958.
# Early stopped.
#   4%|▎         | 72/2000 [00:04<01:52, 17.09it/s, nll=2.37]
# Best Epoch: 46. Best Metric: 2.372984.
# Early stopped.
#  29%|██▉       | 588/2000 [00:29<01:10, 20.08it/s, nll=2.37]
# Best Epoch: 567. Best Metric: 2.371836.
# Early stopped.
#   4%|▎         | 71/2000 [00:04<01:53, 17.01it/s, nll=2.37]
# Best Epoch: 45. Best Metric: 2.370767.
# Early stopped.
#  32%|███▏      | 632/2000 [00:30<01:07, 20.40it/s, nll=2.37]
# Best Epoch: 611. Best Metric: 2.369899.
# Early stopped.
#   4%|▍         | 83/2000 [00:04<01:51, 17.24it/s, nll=2.37]
# Best Epoch: 57. Best Metric: 2.368661.
# Early stopped.
# NK
# (256, 8) (256, 3) (256, 1178)
#   9%|▉         | 177/2000 [00:07<01:19, 22.98it/s, nll=1.55]
# Best Epoch: 156. Best Metric: 1.553531.
# Early stopped.
#   2%|▏         | 31/2000 [00:01<01:53, 17.36it/s, nll=1.55]
# Best Epoch: 5. Best Metric: 1.553748.
# Early stopped.
#  24%|██▍       | 480/2000 [00:21<01:06, 22.82it/s, nll=1.55]
# Best Epoch: 459. Best Metric: 1.548890.
# Early stopped.
#   2%|▏         | 31/2000 [00:01<01:51, 17.65it/s, nll=1.55]
# Best Epoch: 5. Best Metric: 1.549072.
# Early stopped.
#  27%|██▋       | 544/2000 [00:24<01:05, 22.20it/s, nll=1.55]
# Best Epoch: 523. Best Metric: 1.545899.
# Early stopped.
#   2%|▏         | 31/2000 [00:01<01:40, 19.55it/s, nll=1.55]
# Best Epoch: 5. Best Metric: 1.546058.
# Early stopped.
#  29%|██▉       | 581/2000 [00:24<00:59, 23.97it/s, nll=1.54]
# Best Epoch: 560. Best Metric: 1.542829.
# Early stopped.
#   2%|▏         | 31/2000 [00:01<01:48, 18.09it/s, nll=1.54]
# Best Epoch: 5. Best Metric: 1.542969.
# Early stopped.
#  31%|███       | 618/2000 [00:28<01:03, 21.63it/s, nll=1.54]
# Best Epoch: 597. Best Metric: 1.540483.
# Early stopped.
#   2%|▏         | 48/2000 [00:02<01:49, 17.77it/s, nll=1.54]
# Best Epoch: 22. Best Metric: 1.540478.
# Early stopped.
#  32%|███▏      | 646/2000 [00:30<01:03, 21.37it/s, nll=1.54]
# Best Epoch: 625. Best Metric: 1.538739.
# Early stopped.
#   2%|▏         | 42/2000 [00:02<01:54, 17.13it/s, nll=1.54]
# Best Epoch: 16. Best Metric: 1.538716.
# Early stopped.
#  36%|███▌      | 710/2000 [00:32<00:59, 21.83it/s, nll=1.54]
# Best Epoch: 689. Best Metric: 1.536680.
# Early stopped.
#   2%|▏         | 40/2000 [00:02<01:51, 17.55it/s, nll=1.54]
# Best Epoch: 14. Best Metric: 1.536647.
# Early stopped.
#  38%|███▊      | 750/2000 [00:34<00:57, 21.61it/s, nll=1.53]
# Best Epoch: 729. Best Metric: 1.534267.
# Early stopped.
#   3%|▎         | 55/2000 [00:03<01:50, 17.57it/s, nll=1.53]
# Best Epoch: 29. Best Metric: 1.534119.
# Early stopped.
#  39%|███▉      | 785/2000 [00:36<00:56, 21.61it/s, nll=1.53]
# Best Epoch: 764. Best Metric: 1.532534.
# Early stopped.
#   2%|▏         | 47/2000 [00:02<01:43, 18.81it/s, nll=1.53]
# Best Epoch: 21. Best Metric: 1.532376.
# Early stopped.
#  42%|████▏     | 839/2000 [00:37<00:52, 22.17it/s, nll=1.53]
# Best Epoch: 818. Best Metric: 1.530593.
# Early stopped.
#   2%|▏         | 46/2000 [00:02<01:44, 18.61it/s, nll=1.53]
# Best Epoch: 20. Best Metric: 1.530405.
# Early stopped.

# %% [markdown]
# # Details of all cell types

# %%
mad_max_dict = {'T4':1.13, 'cM':1.13, 'B':1.13, 'T8':1.11, 'NK':1.}
med_max_dict = {'T4':.025, 'cM':.025, 'B':.025, 'T8':.08, 'NK':.08}

dict_disc = {}
for cell_type in cell_types[:]:
    file_name = path_data + 'data_lupus_{}.npz'.format(cell_type)
    with open(file_name, 'rb') as f:
        tmp = np.load(f, allow_pickle=True)
        X = tmp['X']
        Y = tmp['Y'].astype(float)
        gene_names = tmp['gene_names'].astype(str)
        X = X * 2 - 1
        X = np.c_[np.ones(X.shape[0]), np.log(np.sum(Y, axis=1)),  X]
        X = X / np.sqrt(np.sum(X**2, 0, keepdims=True)) * np.sqrt(X.shape[0])
        id_genes = np.any(Y!=0, axis=0) & (np.sum(Y>0, axis=0)>=10)
        
        Y = Y[:,id_genes]
        gene_names = gene_names[id_genes]

    n = Y.shape[0]
    X_sub = np.c_[X[:,:2],X[:,-1:]]

    print(cell_type)
    print('\t shape:', X.shape, X_sub.shape, Y.shape)
    print('\t sparsity:',np.mean(Y==0))

    
    with open(path_result+'dill_{}.pkl'.format(cell_type), "rb") as file_object:
        [
            B_glm,tvals,pvals,_df_glm,disp_glm,
            B_glm_nb,tvals_glm_nb,pvals_glm_nb,_df_glm_nb,
            B_glm_sub,tvals_sub,pvals_sub,_df_glm_sub,disp_glm_sub,
            B_glm_nb_sub,tvals_glm_nb_sub,pvals_glm_nb_sub,_df_glm_nb_sub
        ] = dill.load(file_object)

    df_glm_nb = pd.DataFrame({
        'beta_hat':B_glm_nb[:,-1],
        'z_scores':tvals_glm_nb, 
        'p_values':pvals_glm_nb,
        'q_values':multipletests(pvals_glm_nb, alpha=0.05, method='fdr_bh')[1]
    })
    df_glm_nb_sub = pd.DataFrame({
        'beta_hat':B_glm_nb_sub[:,-1],
        'z_scores':tvals_glm_nb_sub, 
        'p_values':pvals_glm_nb_sub,
        'q_values':multipletests(pvals_glm_nb_sub, alpha=0.05, method='fdr_bh')[1]
    })

    df_gcate = pd.read_csv(path_result+'gcate_{}.csv'.format(cell_type))
    fig, (lams, medians, mads) = plot_lam(df_gcate, 
        mad_max=mad_max_dict[cell_type], med_max=med_max_dict[cell_type])
    fig.savefig(path_result + 'lupus_{}_lam.pdf'.format(cell_type), dpi=300, bbox_inches='tight')
    idx = (np.abs(medians) < med_max_dict[cell_type])&(mads < mad_max_dict[cell_type])
    lam = lams[idx][np.argmax(np.abs(mads[idx]))]

    print(lam, lam/np.sqrt(np.log(n)/n))
    df_gcate = df_gcate[df_gcate['lam']==lam].reset_index(drop=True)
    df_cate = pd.read_csv('{}cate_raw_{}.csv'.format(path_result, cell_type))
    df_cate_adj = pd.read_csv('{}cate_{}.csv'.format(path_result, cell_type))

    print('\t GLM discoveries:', np.sum(df_glm_nb['p_values']<0.05), np.sum(df_glm_nb['q_values']<0.2))

    pvals = np.c_[df_glm_nb['p_values'], df_glm_nb_sub['p_values'], df_cate['p_values'],
        df_cate_adj['p_values'], df_gcate['p_values']]
    discoveries = (pvals<0.05)
    TP = (discoveries[:,1:] == 1) & (discoveries[:,:1] == 1)
    FP = (discoveries[:,1:] == 1) & (discoveries[:,:1] == 0)
    print('\t p:', np.sum(TP,axis=0), np.sum(FP,axis=0))

    qvals = np.c_[df_glm_nb['q_values'], df_glm_nb_sub['q_values'], df_cate['q_values'],
        df_cate_adj['q_values'], df_gcate['q_values']]
    discoveries = (qvals<0.2)
    TP = (discoveries[:,1:] == 1) & (discoveries[:,:1] == 1)
    FP = (discoveries[:,1:] == 1) & (discoveries[:,:1] == 0)    
    print('\t q:', np.sum(TP,axis=0), np.sum(FP,axis=0))
    sns.set_theme(style="white", font_scale=1.2)
    fig, axes = plt.subplots(2,3,figsize=(10,6), sharex=False)

    axes[0,0].hist(df_glm_nb['z_scores'], bins=50, density=True, range=[-10,10])
    axes[0,1].hist(df_glm_nb_sub['z_scores'], bins=50, density=True, range=[-10,10])
    axes[0,2].hist(df_cate['z_scores'], bins=50, density=True, range=[-10,10])
    axes[1,0].hist(df_cate_adj['z_scores'], bins=50, density=True, range=[-10,10])
    axes[1,1].hist(df_gcate['z_scores'], bins=50, density=True, range=[-10,10])

    methods = ['GLM-oracle', 'GLM-naive', 'CATE', 'CATE-mad', 'GCATE']
    sns.barplot(data=
                pd.DataFrame({'Methods':methods[1:], 'FDP':np.sum(FP, axis=0) / np.sum(TP + FP, axis=0)})
                , x="Methods", y="FDP", ax=axes[1,2])
    axes[1,2].bar_label(axes[1,2].containers[0], fmt='%.02f')
    for bar, color in zip(axes[1,2].containers[0], sns.color_palette()[:4]):
        bar.set_facecolor(color)

    dict_disc[cell_type] = discoveries

    x_axis = np.arange(-10, 10, 0.001)
    for i in range(2):
        for j in range(3):
            if i==1 and j==2:
                break        
            axes[i,j].plot(x_axis, sp.stats.norm.pdf(x_axis,0,1))
            axes[i,j].set_title(methods[3*i+j])
            axes[i,j].set_ylim([0,0.45])
            if j>0:
                axes[i,j].set_yticks([])
            if i==0:
                axes[i,j].set_xticks([])

    axes[1,2].set_yticks([])
    axes[1,2].set_ylabel('')
    axes[1,2].set_title('FDP')
    axes[1,2].set_ylim([0,1.1])
    axes[1,2].set_xticklabels(axes[1,2].get_xticklabels(), rotation=15, ha='center')
    fig.tight_layout()
    plt.savefig('result/lupus_zscores_{}.pdf'.format(cell_type), bbox_inches='tight', pad_inches=0, dpi=300)
# Out:
# T4
# 	 shape: (256, 8) (256, 3) (256, 1255)
# 	 sparsity: 0.6020760707171314
# 0.0883057516886606 0.6
# 	 GLM discoveries: 156 72
# 	 p: [138  64  29  69] [166 482 179  54]
# 	 q: [72 44 11 15] [228 726 164   1]
# cM
# 	 shape: (256, 8) (256, 3) (256, 1208)
# 	 sparsity: 0.565969707160596
# 0.0500399259569076 0.3399999999999995
# 	 GLM discoveries: 120 51
# 	 p: [94 75 40 65] [203 683 223  50]
# 	 q: [45 44 17 17] [ 247 1051  236    8]
# B
# 	 shape: (254, 8) (254, 3) (254, 1269)
# 	 sparsity: 0.5828695171968752
# 0.0383890053798858 0.25999999999999995
# 	 GLM discoveries: 100 23
# 	 p: [77 47 27 65] [231 519 217  51]
# 	 q: [22 17  5 17] [282 809 207   5]
# T8
# 	 shape: (256, 8) (256, 3) (256, 1281)
# 	 sparsity: 0.529054449648712
# 0.1324586275329909 0.9
# 	 GLM discoveries: 137 31
# 	 p: [120  99  43  53] [266 671 232  69]
# 	 q: [31 26  8 14] [ 399 1108  251    6]
# NK
# 	 shape: (256, 8) (256, 3) (256, 1178)
# 	 sparsity: 0.6154731271222411
# 0.0206046753940208 0.13999999999999996
# 	 GLM discoveries: 65 3
# 	 p: [49 36  9 36] [174 613 192  28]
# 	 q: [3 1 0 0] [167 998 167   0]

# %% [markdown]
# # Figure 7

# %%
cell_type = 'T4'

file_name = path_data + 'data_lupus_{}.npz'.format(cell_type)
with open(file_name, 'rb') as f:
    tmp = np.load(f, allow_pickle=True)
    X = tmp['X']
    Y = tmp['Y'].astype(float)
    gene_names = tmp['gene_names'].astype(str)
    X = X * 2 - 1
    X = np.c_[np.ones(X.shape[0]), 
                np.log(np.sum(Y, axis=1)),  X]
    X = X / np.sqrt(np.sum(X**2, 0, keepdims=True)) * np.sqrt(X.shape[0])
    id_genes = np.any(Y!=0, axis=0) & (np.sum(Y>0, axis=0)>=10)
    
    Y = Y[:,id_genes]
    gene_names = gene_names[id_genes]
    
X_sub = np.c_[X[:,:2],X[:,-1:]]
Y_norm = np.log1p(Y/np.sum(Y,axis=0,keepdims=True)*1e4)

# %%
stat = []
for cell_type in cell_types:
    arr = dict_disc[cell_type]
    num = arr.shape[0]
    TP = (arr[:,1:] == 1) & (arr[:,:1] == 1)
    FP = (arr[:,1:] == 1) & (arr[:,:1] == 0)
    TN = ((arr[:,1:] == 0) & (arr[:,:1] == 0))
    FN = ((arr[:,1:] == 0) & (arr[:,:1] == 1))
    
    stat.append(
        np.c_[
            np.sum(TP, axis=0)/np.sum(TP+FP, axis=0), 
            np.sum(TN, axis=0)/np.sum(TN+FP, axis=0)
        ]
    )
        
stat = np.stack(stat, axis=0)
df_stat = pd.DataFrame()
for j, metric in enumerate(['Precision', 'Specificity']):
    
    _df = pd.DataFrame(stat[:,:,j], columns=methods[1:])
    _df['Metric'] = metric
    _df['Cell type'] = cell_types
    df_stat = pd.concat([df_stat, _df], axis=0)


df_stat = df_stat.set_index(['Cell type', 'Metric'])

df_stat = df_stat.stack().reset_index()
df_stat.columns = ['Cell type', 'Metric', 'Method', 'Value']

# %%
cell_type = 'T4'

with open(path_result+'dill_{}.pkl'.format(cell_type), "rb") as file_object:
    [
        B_glm,tvals,pvals,_df_glm,disp_glm,
        B_glm_nb,tvals_glm_nb,pvals_glm_nb,_df_glm_nb,
        B_glm_sub,tvals_sub,pvals_sub,_df_glm_sub,disp_glm_sub,
        B_glm_nb_sub,tvals_glm_nb_sub,pvals_glm_nb_sub,_df_glm_nb_sub
    ] = dill.load(file_object)

df_glm_nb = pd.DataFrame({
    'beta_hat':B_glm_nb[:,-1],
    'z_scores':tvals_glm_nb, 
    'p_values':pvals_glm_nb,
    'q_values':multipletests(pvals_glm_nb, alpha=0.05, method='fdr_bh')[1]
})
df_glm_nb_sub = pd.DataFrame({
    'beta_hat':B_glm_nb_sub[:,-1],
    'z_scores':tvals_glm_nb_sub, 
    'p_values':pvals_glm_nb_sub,
    'q_values':multipletests(pvals_glm_nb_sub, alpha=0.05, method='fdr_bh')[1]
})


df_gcate = pd.read_csv(path_result+'gcate_{}.csv'.format(cell_type))
from gcate import estimate_lam
lams, medians, mads = estimate_lam(df_gcate)
idx = (mads<=1.3)
lam = lams[idx][np.argmin(mads[idx])]
df_gcate = df_gcate[df_gcate['lam']==lam].reset_index(drop=True)
df_cate = pd.read_csv('{}cate_raw_{}.csv'.format(path_result, cell_type))
df_cate_adj = pd.read_csv('{}cate_{}.csv'.format(path_result, cell_type))


sns.set_theme(style="white", font_scale=1.2)
fig, axes = plt.subplots(2,3,figsize=(12,6), sharex=False)

axes[0,0].hist(df_glm_nb['z_scores'], bins=50, density=True, range=[-10,10])
axes[0,1].hist(df_glm_nb_sub['z_scores'], bins=50, density=True, range=[-10,10])
axes[0,2].hist(df_cate['z_scores'], bins=50, density=True, range=[-10,10])
axes[1,0].hist(df_cate_adj['z_scores'], bins=50, density=True, range=[-10,10])
axes[1,1].hist(df_gcate['z_scores'], bins=50, density=True, range=[-10,10])

methods = ['GLM-oracle', 'GLM-naive', 'CATE', 'CATE-mad', 'GCATE']


x_axis = np.arange(-10, 10, 0.001)
for i in range(2):
    for j in range(3):
        if i==1 and j==2:
            break        
        axes[i,j].plot(x_axis, sp.stats.norm.pdf(x_axis,0,1))
        axes[i,j].set_title(methods[3*i+j])
        axes[i,j].set_ylim([0,0.45])
        if j>0:
            axes[i,j].set_yticks([])
        if i==0:
            axes[i,j].set_xticks([])

sns.violinplot(data=df_stat, x='Method', y='Value', hue='Metric', density_norm='width', cut=0, axes=axes[1,2])

axes[1,2].set_yticks([0,0.5,1], fontsize=8)
axes[1,2].set_ylabel('')

sns.move_legend(axes[1,2], "lower center",
    bbox_to_anchor=(.51, 1), ncol=3, title=None, frameon=False, fontsize=10
               )
fig.subplots_adjust(wspace=0.05, hspace=0.2)
fig.tight_layout()

plt.figtext(0.02, 0.95, '(a)', weight='bold', fontsize=16)
plt.figtext(0.67, 0.5, '(b)', weight='bold', fontsize=16)

plt.savefig('result/lupus_zscores.pdf', bbox_inches='tight', pad_inches=0, dpi=300)

# %%
# save results for GO analysis
qvals = np.c_[df_glm_nb['q_values'], df_glm_nb_sub['q_values'], df_cate['q_values'],
        df_cate_adj['q_values'], df_gcate['q_values']]
pd.DataFrame(qvals<0.2, index=gene_names).to_csv('result/lupus_discoveries_T4.csv')   

# sub_gene_names = gene_names[(df_gcate['q_values']<=0.2)&(df_glm_nb['q_values']<=0.2)]
# sub_gene_names[~np.isin(sub_gene_names, de_gene_names)]

# %% [markdown]
# # Figures G1 and G2

# %%
x_axis = np.arange(-10, 10, 0.001)
sns.set_theme(style="white", font_scale=1.2)
fig, axes = plt.subplots(1,4,figsize=(16,4),sharex=True,sharey=True)
for i,cell_type in enumerate(cell_types):
    _df_cate = pd.read_csv('{}cate_raw_{}_250.csv'.format(path_result, cell_type))

    
    axes[i].hist(_df_cate['z_scores'], bins=50, density=True, range=[-10,10])
    axes[i].set_ylim([0,0.45])
    axes[i].set_title(cell_type)
    axes[i].plot(x_axis, sp.stats.norm.pdf(x_axis,0,1))

fig.tight_layout()
plt.savefig('result/lupus_cate_250.pdf', bbox_inches='tight', pad_inches=0, dpi=300)

# %%
sns.set_theme(style="white", font_scale=1.2)
fig, axes = plt.subplots(2,5,figsize=(12,5))
for j in range(5):
    axes[0,j].hist(Y[:,j], bins=np.arange(0,101,2), range=(0,100))
    axes[1,j].hist(Y_norm[:,j], bins=np.arange(11), range=(0,10))
    axes[0,j].set_title(gene_names[j])
    
fig.tight_layout()
plt.savefig('result/lupus_hist_count.pdf', bbox_inches='tight', pad_inches=0, dpi=300)

# %% [markdown]
# # Table G3

# %%
from gcate.likelihood import log_h, nll

r_dict = {}
cell_type = 'T4'
file_name = path_data + 'data_lupus_{}.npz'.format(cell_type)
with open(file_name, 'rb') as f:
    tmp = np.load(f, allow_pickle=True)
    X = tmp['X']
    Y = tmp['Y'].astype(float)
    gene_names = tmp['gene_names'].astype(str)
    X = X * 2 - 1
    X = np.c_[np.ones(X.shape[0]), 
                np.log(np.sum(Y, axis=1)),  X]
    X = X / np.sqrt(np.sum(X**2, 0, keepdims=True)) * np.sqrt(X.shape[0])
    id_genes = np.any(Y!=0, axis=0) & (np.sum(Y>0, axis=0)>=10)
    Y = Y[:,id_genes]
    gene_names = gene_names[id_genes]

    
X_sub = np.c_[X[:,:2],X[:,-1:]]
n, p = Y.shape
d = X_sub.shape[1]


with open(path_result+'dill_{}.pkl'.format(cell_type), "rb") as file_object:
    [
        B_glm,tvals,pvals,_df_glm,disp_glm,
        B_glm_nb,tvals_glm_nb,pvals_glm_nb,_df_glm_nb,
        B_glm_sub,tvals_sub,pvals_sub,_df_glm_sub,disp_glm_sub,
        B_glm_nb_sub,tvals_glm_nb_sub,pvals_glm_nb_sub,_df_glm_nb_sub
    ] = dill.load(file_object)

df_glm_nb = pd.DataFrame({
    'beta_hat':B_glm_nb[:,-1],
    'z_scores':tvals_glm_nb, 
    'p_values':pvals_glm_nb,
    'q_values':multipletests(pvals_glm_nb, alpha=0.05, method='fdr_bh')[1]
})
df_glm_nb_sub = pd.DataFrame({
    'beta_hat':B_glm_nb_sub[:,-1],
    'z_scores':tvals_glm_nb_sub, 
    'p_values':pvals_glm_nb_sub,
    'q_values':multipletests(pvals_glm_nb_sub, alpha=0.05, method='fdr_bh')[1]
})


with open('result/lupus/dill_{}.pkl'.format(cell_type), "rb") as file_object:
    [
        B_glm,tvals,pvals,_df_glm,disp_glm,
        B_glm_nb,tvals_glm_nb,pvals_glm_nb,_df_glm_nb,
        B_glm_sub,tvals_sub,pvals_sub,_df_glm_sub,disp_glm_sub,
        B_glm_nb_sub,tvals_glm_nb_sub,pvals_glm_nb_sub,_df_glm_nb_sub
    ] = dill.load(file_object)
    
    
kwargs_glm = {
    'family':'negative_binomial',
    'nuisance':1/disp_glm_sub[None,:]
}

df_stat = []
for r in range(1,11):
    with open(path_result+'dill_{}_gcate_r_{}.pkl'.format(cell_type, r), "rb") as file_object:
        [
            A01, A02, A1, A2, P_Gamma, B_de, se
        ] = dill.load(file_object) 
    
    logh = log_h(Y, kwargs_glm['family'], kwargs_glm['nuisance'])
    
    deviance = 2 * ( 
        nll(Y, A1, A2, kwargs_glm['family'], kwargs_glm['nuisance']) / p 
        - np.sum(logh) / (n*p) ) 
    nu = (d + r) * np.maximum(n,p) * np.log(n * p / np.maximum(n,p)) / (n*p)
    jic = deviance + 0.25 * nu
    
    z_scores = (B_de[:,0] / se[:,0])
    z_scores[np.isnan(z_scores)] = np.nanmedian(z_scores)
    pvals = sp.stats.norm.sf(np.abs(z_scores))*2
    df_gcate = pd.DataFrame({
        'z_scores':z_scores, 
        'p_values':pvals,
        'q_values':multipletests(pvals, alpha=0.05, method='fdr_bh')[1]
    })

    df_stat.append([r, np.mean(df_gcate['z_scores']), np.median(df_gcate['z_scores']), np.std(df_gcate['z_scores']),
        sp.stats.median_abs_deviation(z_scores, scale="normal", nan_policy='omit'), 
        sp.stats.skew(z_scores), np.sum(df_gcate['q_values']<0.2), deviance, jic
    ])
    

print(pd.DataFrame(df_stat, columns=['r', 'mean', 'median', 'std', 
                               'mad', 'skewness', 'num_sig', 'deviance', 'JIC'])[
    ['r', 'mean', 'median', 'mad', 'num_sig', 'deviance', 'JIC']].to_latex(
    index=False, float_format="{:.3f}".format,
)  )
# Out:
# \begin{tabular}{rrrrrrr}
# \toprule
# r & mean & median & mad & num_sig & deviance & JIC \\
# \midrule
# 1 & 0.348 & -0.018 & 1.551 & 302 & 3.578 & 3.600 \\
# 2 & 0.361 & -0.040 & 1.539 & 313 & 3.565 & 3.592 \\
# 3 & 0.141 & -0.001 & 1.145 & 57 & 3.553 & 3.586 \\
# 4 & 0.140 & 0.063 & 1.087 & 37 & 3.546 & 3.584 \\
# 5 & 0.130 & 0.043 & 1.067 & 33 & 3.539 & 3.582 \\
# 6 & 0.140 & 0.051 & 1.084 & 39 & 3.532 & 3.581 \\
# 7 & 0.128 & 0.057 & 1.033 & 22 & 3.526 & 3.580 \\
# 8 & 0.139 & 0.069 & 1.044 & 18 & 3.521 & 3.580 \\
# 9 & 0.143 & 0.073 & 1.032 & 18 & 3.516 & 3.581 \\
# 10 & 0.155 & 0.095 & 1.038 & 20 & 3.513 & 3.583 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Figure G3

# %%
sns.set_theme(style="white", font_scale=1.2)
fig, axes = plt.subplots(5,4,figsize=(10,12), sharex=True, sharey=True)
    
dict_disc = {}
for i,cell_type in enumerate(cell_types[1:]):
    file_name = path_data + 'data_lupus_{}.npz'.format(cell_type)
    with open(file_name, 'rb') as f:
        tmp = np.load(f, allow_pickle=True)
        X = tmp['X']
        Y = tmp['Y'].astype(float)
        gene_names = tmp['gene_names'].astype(str)
        X = X * 2 - 1
        X = np.c_[np.ones(X.shape[0]), 
                  np.log(np.sum(Y, axis=1)),  X]
        
        X = X / np.sqrt(np.sum(X**2, 0, keepdims=True)) * np.sqrt(X.shape[0])
        id_genes = np.any(Y!=0, axis=0) & (np.sum(Y>0, axis=0)>=10)
        
        Y = Y[:,id_genes]
        gene_names = gene_names[id_genes]

        
    X_sub = np.c_[X[:,:2],X[:,-1:]]

    print(cell_type)
    print('\t shape:', X.shape, X_sub.shape, Y.shape)
    print('\t sparsity:',np.mean(Y==0))

    
    with open(path_result+'dill_{}.pkl'.format(cell_type), "rb") as file_object:
        [
            B_glm,tvals,pvals,_df_glm,disp_glm,
            B_glm_nb,tvals_glm_nb,pvals_glm_nb,_df_glm_nb,
            B_glm_sub,tvals_sub,pvals_sub,_df_glm_sub,disp_glm_sub,
            B_glm_nb_sub,tvals_glm_nb_sub,pvals_glm_nb_sub,_df_glm_nb_sub
        ] = dill.load(file_object)

    df_glm_nb = pd.DataFrame({
        'beta_hat':B_glm_nb[:,-1],
        'z_scores':tvals_glm_nb, 
        'p_values':pvals_glm_nb,
        'q_values':multipletests(pvals_glm_nb, alpha=0.05, method='fdr_bh')[1]
    })
    df_glm_nb_sub = pd.DataFrame({
        'beta_hat':B_glm_nb_sub[:,-1],
        'z_scores':tvals_glm_nb_sub, 
        'p_values':pvals_glm_nb_sub,
        'q_values':multipletests(pvals_glm_nb_sub, alpha=0.05, method='fdr_bh')[1]
    })

    df_gcate = pd.read_csv(path_result+'gcate_{}.csv'.format(cell_type))
    lams, medians, mads = estimate_lam(df_gcate)
    idx = (np.abs(medians) < med_max_dict[cell_type])&(mads < mad_max_dict[cell_type])
    lam = lams[idx][np.argmax(np.abs(mads[idx]))]
    
    df_gcate = df_gcate[df_gcate['lam']==lam].reset_index(drop=True)
    df_cate = pd.read_csv('{}cate_raw_{}.csv'.format(path_result, cell_type))
    df_cate_adj = pd.read_csv('{}cate_{}.csv'.format(path_result, cell_type))

    qvals = np.c_[df_glm_nb['q_values'], df_glm_nb_sub['q_values'], df_cate['q_values'],
    df_cate_adj['q_values'], df_gcate['q_values']]
    discoveries = (qvals<0.2)

    TP = (discoveries[:,1:] == 1) & (discoveries[:,:1] == 1)
    FP = (discoveries[:,1:] == 1) & (discoveries[:,:1] == 0)

    print('\t GLM discoveries:', np.sum(df_glm_nb['p_values']<0.05), np.sum(df_glm_nb['q_values']<0.2))
    print('\t ', np.sum(TP,axis=0), np.sum(FP,axis=0))
    
    axes[0,i].hist(df_glm_nb['z_scores'], bins=50, density=True, range=[-10,10])
    axes[1,i].hist(df_glm_nb_sub['z_scores'], bins=50, density=True, range=[-10,10])
    axes[2,i].hist(df_cate['z_scores'], bins=50, density=True, range=[-10,10])
    axes[3,i].hist(df_cate_adj['z_scores'], bins=50, density=True, range=[-10,10])
    axes[4,i].hist(df_gcate['z_scores'], bins=50, density=True, range=[-10,10])

methods = ['GLM-oracle', 'GLM-naive', 'CATE', 'CATE-mad', 'GCATE']

x_axis = np.arange(-10, 10, 0.001)
for i in range(5):
    for j in range(4):
        axes[i,j].plot(x_axis, sp.stats.norm.pdf(x_axis,0,1))
        
        axes[i,j].set_ylim([0,0.45])
        if j>0:
            axes[i,j].set_yticks([])
            axes[i,j].set_ylabel('')
        else:
            axes[i,j].set_ylabel(methods[i])
        if i==0:
            axes[i,j].set_xticks([])
            axes[i,j].set_title(cell_types[j+1])
            

fig.tight_layout()
plt.savefig('result/lupus_zscores_others.pdf', bbox_inches='tight', pad_inches=0, dpi=300)
# Out:
# cM
# 	 shape: (256, 8) (256, 3) (256, 1208)
# 	 sparsity: 0.565969707160596
# 	 GLM discoveries: 120 51
# 	  [45 44 17 17] [ 247 1051  236    8]
# B
# 	 shape: (254, 8) (254, 3) (254, 1269)
# 	 sparsity: 0.5828695171968752
# 	 GLM discoveries: 100 23
# 	  [22 17  5 17] [282 809 207   5]
# T8
# 	 shape: (256, 8) (256, 3) (256, 1281)
# 	 sparsity: 0.529054449648712
# 	 GLM discoveries: 137 31
# 	  [31 26  8 14] [ 399 1108  251    6]
# NK
# 	 shape: (256, 8) (256, 3) (256, 1178)
# 	 sparsity: 0.6154731271222411
# 	 GLM discoveries: 65 3
# 	  [3 1 0 0] [167 998 167   0]

# %% [markdown]
# # Table G4

# %%
res = []
for cell_type in cell_types:
    file_name = path_data + 'data_lupus_{}.npz'.format(cell_type)
    with open(file_name, 'rb') as f:
        tmp = np.load(f, allow_pickle=True)
        X = tmp['X']
        Y = tmp['Y'].astype(float)
        gene_names = tmp['gene_names'].astype(str)
        X = X * 2 - 1
        X = np.c_[np.ones(X.shape[0]), 
                  np.log(np.sum(Y, axis=1)),  X]
        
        X = X / np.sqrt(np.sum(X**2, 0, keepdims=True)) * np.sqrt(X.shape[0])
        id_genes = np.any(Y!=0, axis=0) & (np.sum(Y>0, axis=0)>=10)
        
        Y = Y[:,id_genes]
        gene_names = gene_names[id_genes]

    res.append([cell_type, Y.shape[0], Y.shape[1], np.mean(Y!=0)])
    
print(pd.DataFrame(res, columns=['Cell type', 'Number of samples', 'Number of genes', 'Sparsity']).to_latex(
    index=False, float_format="{:.3f}".format,
))
# Out:
# \begin{tabular}{lrrr}
# \toprule
# Cell type & Number of samples & Number of genes & Sparsity \\
# \midrule
# T4 & 256 & 1255 & 0.398 \\
# cM & 256 & 1208 & 0.434 \\
# B & 254 & 1269 & 0.417 \\
# T8 & 256 & 1281 & 0.471 \\
# NK & 256 & 1178 & 0.385 \\
# \bottomrule
# \end{tabular}
